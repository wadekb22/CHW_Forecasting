# %%
import pandas as pd

ts = pd.read_csv("merged_data.csv", index_col='DATE', parse_dates=True)
ts.head()
# Out:
#                      Unnamed: 0  Total Power (max)  Total Power (min)  \
# DATE
# 2019-03-01 00:00:00           0                0.0                0.0
# 2019-03-01 01:00:00           1                0.0                0.0
# 2019-03-01 02:00:00           2                0.0                0.0
# 2019-03-01 03:00:00           3                0.0                0.0
# 2019-03-01 04:00:00           4                0.0                0.0
#
#                      Total Power (avg)  Total Power (samp)  \
# DATE
# 2019-03-01 00:00:00                0.0                 0.0
# 2019-03-01 01:00:00                0.0                 0.0
# 2019-03-01 02:00:00                0.0                 0.0
# 2019-03-01 03:00:00                0.0                 0.0
# 2019-03-01 04:00:00                0.0                 0.0
#
#                      Total Power (trimmed)  HourlyDewPointTemperature  \
# DATE
# 2019-03-01 00:00:00                    0.0                        9.0
# ...

# %%
ts.drop('Unnamed: 0', axis=1, inplace=True)
ts.head()
# Out:
#                      Total Power (max)  Total Power (min)  Total Power (avg)  \
# DATE
# 2019-03-01 00:00:00                0.0                0.0                0.0
# 2019-03-01 01:00:00                0.0                0.0                0.0
# 2019-03-01 02:00:00                0.0                0.0                0.0
# 2019-03-01 03:00:00                0.0                0.0                0.0
# 2019-03-01 04:00:00                0.0                0.0                0.0
#
#                      Total Power (samp)  Total Power (trimmed)  \
# DATE
# 2019-03-01 00:00:00                 0.0                    0.0
# 2019-03-01 01:00:00                 0.0                    0.0
# 2019-03-01 02:00:00                 0.0                    0.0
# 2019-03-01 03:00:00                 0.0                    0.0
# 2019-03-01 04:00:00                 0.0                    0.0
#
#                      HourlyDewPointTemperature  HourlyDryBulbTemperature  \
# DATE
# ...

# %%
ts.columns
# Out:
# Index(['Total Power (max)', 'Total Power (min)', 'Total Power (avg)',
#        'Total Power (samp)', 'Total Power (trimmed)',
#        'HourlyDewPointTemperature', 'HourlyDryBulbTemperature',
#        'HourlyPrecipitation', 'HourlyRelativeHumidity', 'HourlySkyConditions',
#        'HourlyStationPressure', 'HourlyVisibility', 'HourlyWetBulbTemperature',
#        'HourlyWindDirection', 'HourlyWindSpeed', 'BC', 'BL', 'BR', 'DZ', 'FG',
#        'FZ', 'GS', 'HZ', 'MI', 'PL', 'RA', 'SN', 'TS', 'VCTS'],
#       dtype='object')

# %%
from dateutil.parser import parse

ts2 = pd.read_csv("merged_data.csv")

date_series = ts2["DATE"]
print("Original Series:")
print(date_series)
date_series = date_series.map(lambda x: parse(x))
print("Day of week:")
weekday = list(date_series.dt.day_name())

ts["Weekday"] = weekday
# Out:
# Original Series:
# 0        2019-03-01 00:00:00
# 1        2019-03-01 01:00:00
# 2        2019-03-01 02:00:00
# 3        2019-03-01 03:00:00
# 4        2019-03-01 04:00:00
#                 ...
# 17539    2021-02-28 19:00:00
# 17540    2021-02-28 20:00:00
# 17541    2021-02-28 21:00:00
# 17542    2021-02-28 22:00:00
# 17543    2021-02-28 23:00:00
# Name: DATE, Length: 17544, dtype: object
# Day of week:

# %%
ts["Weekday"] = weekday
ts.head()
# Out:
#                      Total Power (max)  Total Power (min)  Total Power (avg)  \
# DATE
# 2019-03-01 00:00:00                0.0                0.0                0.0
# 2019-03-01 01:00:00                0.0                0.0                0.0
# 2019-03-01 02:00:00                0.0                0.0                0.0
# 2019-03-01 03:00:00                0.0                0.0                0.0
# 2019-03-01 04:00:00                0.0                0.0                0.0
#
#                      Total Power (samp)  Total Power (trimmed)  \
# DATE
# 2019-03-01 00:00:00                 0.0                    0.0
# 2019-03-01 01:00:00                 0.0                    0.0
# 2019-03-01 02:00:00                 0.0                    0.0
# 2019-03-01 03:00:00                 0.0                    0.0
# 2019-03-01 04:00:00                 0.0                    0.0
#
#                      HourlyDewPointTemperature  HourlyDryBulbTemperature  \
# DATE
# ...

# %%
daily_max = ts[["Total Power (max)", "Weekday"]].resample('D').max()
daily_max.tail()
# Out:
#             Total Power (max)    Weekday
# DATE
# 2021-02-24        2287.482666  Wednesday
# 2021-02-25           2.623183   Thursday
# 2021-02-26           1.191052     Friday
# 2021-02-27        4780.646973   Saturday
# 2021-02-28        1422.560181     Sunday

# %%
spring_dm = daily_max["2020-03-01":"2020-06-01"]
summer_dm = daily_max["2020-06-01":"2020-09-01"]
fall_dm = daily_max["2020-09-01":"2020-12-01"]
winter_dm = daily_max["2020-12-01":"2021-02-28"]

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns
#sns.set_theme(style="whitegrid")
#tips = sns.load_dataset("tips")
ax = sns.barplot(x="Weekday", y="Total Power (max)", data=spring_dm)

# %%
plt.figure(figsize=(10,5))
chart = sns.barplot(x="Weekday", y="Total Power (max)", data=spring_dm)

chart.set_xticklabels(
    chart.get_xticklabels(), 
    rotation=45, 
    horizontalalignment='right',
    fontweight='light',
    fontsize='x-large'
    
)

chart.set_title("Average Max Power Distributed by Week in the Spring",fontsize=20)
chart.set_ylabel("Max Power (tons)",fontsize=18)
chart.set_xlabel("Weekday (a)",fontsize=18)
# Out:
# Text(0.5, 0, 'Weekday (a)')

# %%
summer_dm = summer_dm.iloc[6:]
summer_dm.head()
# Out:
#             Total Power (max)    Weekday
# DATE
# 2020-06-07        9512.809814     Sunday
# 2020-06-08       10923.112793     Monday
# 2020-06-09       15502.480225    Tuesday
# 2020-06-10       20129.720703  Wednesday
# 2020-06-11       17705.482422   Thursday

# %%
plt.figure(figsize=(10,5))
chart = sns.barplot(x="Weekday", y="Total Power (max)", data=summer_dm)

chart.set_xticklabels(
    chart.get_xticklabels(), 
    rotation=45, 
    horizontalalignment='right',
    fontweight='light',
    fontsize='x-large'
    
)

chart.set_title("Average Max Power Distributed by Week in the Summer",fontsize=20)
chart.set_ylabel("Max Power (tons)",fontsize=18)
chart.set_xlabel("Weekday (b)",fontsize=18)
# Out:
# Text(0.5, 0, 'Weekday (b)')

# %%
fall_dm = fall_dm.iloc[5:]
fall_dm.head()
# Out:
#             Total Power (max)    Weekday
# DATE
# 2020-09-06       11575.073242     Sunday
# 2020-09-07       14083.440430     Monday
# 2020-09-08       16975.610840    Tuesday
# 2020-09-09       17454.031005  Wednesday
# 2020-09-10       15626.478027   Thursday

# %%
plt.figure(figsize=(10,5))
chart = sns.barplot(x="Weekday", y="Total Power (max)", data=fall_dm)

chart.set_xticklabels(
    chart.get_xticklabels(), 
    rotation=45, 
    horizontalalignment='right',
    fontweight='light',
    fontsize='x-large'
    
)

chart.set_title("Average Max Power Distributed by Week in the Fall",fontsize=20)
chart.set_ylabel("Max Power (tons)",fontsize=18)
chart.set_xlabel("Weekday (c)",fontsize=18)
# Out:
# Text(0.5, 0, 'Weekday (c)')

# %%
winter_dm = winter_dm.iloc[5:]
winter_dm.head()
# Out:
#             Total Power (max)    Weekday
# DATE
# 2020-12-06         2379.15625     Sunday
# 2020-12-07         2429.87500     Monday
# 2020-12-08         2387.65625    Tuesday
# 2020-12-09         2393.93750  Wednesday
# 2020-12-10         2416.50000   Thursday

# %%
plt.figure(figsize=(10,5))
chart = sns.barplot(x="Weekday", y="Total Power (max)", data=winter_dm)

chart.set_xticklabels(
    chart.get_xticklabels(), 
    rotation=45, 
    horizontalalignment='right',
    fontweight='light',
    fontsize='x-large'
    
)

chart.set_title("Average Max Power Distributed by Week in the Winter",fontsize=20)
chart.set_ylabel("Max Power (tons)",fontsize=18)
chart.set_xlabel("Weekday (d)",fontsize=18)
# Out:
# Text(0.5, 0, 'Weekday (d)')

# %%
plt.figure(figsize=(8,4))
chart = sns.barplot(x="Weekday", y="Total Power (max)", data=summer_dm)

chart.set_xticklabels(
    chart.get_xticklabels(), 
    rotation=45, 
    horizontalalignment='right',
    fontweight='light',
    fontsize='x-large'
    
)

chart.set_title("Average Max Power Distributed by Week in the Summer",fontsize=20)
chart.set_ylabel("Max Power",fontsize=18)
chart.set_xlabel("Weekday",fontsize=18)
# Out:
# Text(0.5, 0, 'Weekday')

# %%
spring_ts = ts["2020-03-01":"2020-06-01"]
summer_ts = ts["2020-06-01":"2020-09-01"]
fall_ts = ts["2020-09-01":"2020-12-01"]
winter_ts = ts["2020-12-01":"2021-02-28"]

# %%
ts2 = pd.read_csv("merged_data.csv")

date_series = ts2["DATE"]
print("Original Series:")
print(date_series)
date_series = date_series.map(lambda x: parse(x))
print("Day of week:")
hour = date_series.dt.hour.tolist()

ts["Hour"] = hour
# Out:
# Original Series:
# 0        2019-03-01 00:00:00
# 1        2019-03-01 01:00:00
# 2        2019-03-01 02:00:00
# 3        2019-03-01 03:00:00
# 4        2019-03-01 04:00:00
#                 ...
# 17539    2021-02-28 19:00:00
# 17540    2021-02-28 20:00:00
# 17541    2021-02-28 21:00:00
# 17542    2021-02-28 22:00:00
# 17543    2021-02-28 23:00:00
# Name: DATE, Length: 17544, dtype: object
# Day of week:

# %%
ts_h = ts[["Total Power (max)", "Hour"]]
spring_ts = ts_h["2020-03-01":"2020-06-01"]
summer_ts = ts_h["2020-06-01":"2020-09-01"]
fall_ts = ts_h["2020-09-01":"2020-12-01"]
winter_ts = ts_h["2020-12-01":"2021-02-28"]

# %%
plt.figure(figsize=(10,5))
chart = sns.barplot(x="Hour", y="Total Power (max)", data=spring_ts)

chart.set_xticklabels(
    chart.get_xticklabels(), 
    rotation=45, 
    #horizontalalignment='right',
    fontweight='light',
    fontsize=16
    
)

chart.set_title("Average Max Power Distributed by Hour in the Spring",fontsize=20)
chart.set_ylabel("Max Power (tons)",fontsize=18)
chart.set_xlabel("Hour (a)",fontsize=18)
# Out:
# Text(0.5, 0, 'Hour (a)')

# %%
plt.figure(figsize=(10,5))
chart = sns.barplot(x="Hour", y="Total Power (max)", data=summer_ts)

chart.set_xticklabels(
    chart.get_xticklabels(), 
    rotation=45, 
    #horizontalalignment='right',
    fontweight='light',
    fontsize=16
    
)

chart.set_title("Average Max Power Distributed by Hour in the Summer",fontsize=20)
chart.set_ylabel("Max Power (tons)",fontsize=18)
chart.set_xlabel("Hour (b)",fontsize=18)
# Out:
# Text(0.5, 0, 'Hour (b)')

# %%
plt.figure(figsize=(10,5))
chart = sns.barplot(x="Hour", y="Total Power (max)", data=fall_ts)

chart.set_xticklabels(
    chart.get_xticklabels(), 
    rotation=45, 
    #horizontalalignment='right',
    fontweight='light',
    fontsize=16
    
)

chart.set_title("Average Max Power Distributed by Hour in the Fall",fontsize=20)
chart.set_ylabel("Max Power (tons)",fontsize=18)
chart.set_xlabel("Hour (c)",fontsize=18)
# Out:
# Text(0.5, 0, 'Hour (c)')

# %%
plt.figure(figsize=(10,5))
chart = sns.barplot(x="Hour", y="Total Power (max)", data=winter_ts)

chart.set_xticklabels(
    chart.get_xticklabels(), 
    rotation=45, 
    #horizontalalignment='right',
    fontweight='light',
    fontsize=16
    
)

chart.set_title("Average Max Power Distributed by Hour in the Winter",fontsize=20)
chart.set_ylabel("Max Power (tons)",fontsize=18)
chart.set_xlabel("Hour (d)",fontsize=18)
# Out:
# Text(0.5, 0, 'Hour (d)')

# %%
data_tp = ts['Total Power (max)']

# %%
! pip install chart_studio
from statsmodels.tsa.seasonal import seasonal_decompose
import matplotlib as mpl
plt.figure()
result = seasonal_decompose(data_tp["2019-08"], model='multiplicative')


with mpl.rc_context():
    mpl.rc("figure", figsize=(14,10))
    
    result.plot()
